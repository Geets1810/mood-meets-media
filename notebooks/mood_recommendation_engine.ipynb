# %% [markdown]
# # 🎯 Mood Meets Media: Mood-Based Recommendation Engine

# %%
import pandas as pd
import random

# %%
# Load processed datasets
mood_logs = pd.read_csv("C:/Users/Vanathi/mood-meets-media/data/processed/enriched_mood_logs.csv")
media = pd.read_csv("C:/Users/Vanathi/mood-meets-media/data/processed/netflix_enriched_metadata_hybrid.csv")

# %%
# Define recommendation function
def recommend_by_mood(user_mood, media_df, top_n=5):
    mood_filtered = media_df[media_df['mood_tag_standard'] == user_mood]
    if len(mood_filtered) >= top_n:
        return mood_filtered.sample(n=top_n, random_state=42)
    else:
        return mood_filtered

# %%
# Get most recent mood and recommend content
latest_mood = mood_logs.sort_values(by="date", ascending=False)["mood"].iloc[0]
print(f"🧠 Latest detected mood: {latest_mood}\n")
recommendations = recommend_by_mood(latest_mood, media)
recommendations[["title", "type", "genre", "tags", "mood_tag_standard"]]
# Out:
# 🧠 Latest detected mood: Happy
#                       title     type  \
# 2895         System Crasher    Movie
# 6014               42 Grams    Movie
# 1038         Dancing Angels  TV Show
# 838   Soy Rada: Serendipity    Movie
# 2435      Life's Speed Bump    Movie
#
#                                                   genre  \
# 2895   Dramas, Independent Movies, International Movies
# 6014                                      Documentaries
# 1038  International TV Shows, Romantic TV Shows, TV ...
# 838                                     Stand-Up Comedy
# 2435                     Comedies, International Movies
#
#                                                    tags mood_tag_standard
# 2895  Traumatized, violent and yearning for love, 9-...             Happy
# 6014  After launching a successful underground resta...             Happy
# 1038  A group of aspiring young musicians yearn for ...             Happy
# 838   The delightful Argentine comic AgustÃ­n Arista...             Happy
# 2435  Seeking job opportunities, a young man arrives...             Happy

# %%
import sys
# !{sys.executable} -m pip install streamlit --user
# Out:
# Collecting streamlit
#   WARNING: The script normalizer.exe is installed in 'C:\Users\Vanathi\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it.exe is installed in 'C:\Users\Vanathi\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pygmentize.exe is installed in 'C:\Users\Vanathi\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script streamlit.exe is installed in 'C:\Users\Vanathi\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# spyder 4.1.5 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.1.5 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
#   Using cached streamlit-1.40.1-py2.py3-none-any.whl (8.6 MB)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\vanathi\anaconda3\lib\site-packages (from streamlit) (1.24.4)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\vanathi\anaconda3\lib\site-packages (from streamlit) (4.13.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\vanathi\anaconda3\lib\site-packages (from streamlit) (7.1.2)
# Collecting tenacity<10,>=8.1.0
#   Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\vanathi\anaconda3\lib\site-packages (from streamlit) (0.10.1)
# Collecting pandas<3,>=1.4.0
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\vanathi\anaconda3\lib\site-packages (from streamlit) (8.0.1)
# Collecting altair<6,>=4.0
#   Using cached altair-5.4.1-py3-none-any.whl (658 kB)
# Requirement already satisfied: packaging<25,>=20 in c:\users\vanathi\anaconda3\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\vanathi\anaconda3\lib\site-packages (from streamlit) (6.0.4)
# Requirement already satisfied: watchdog<7,>=2.1.5; platform_system != "Darwin" in c:\users\vanathi\anaconda3\lib\site-packages (from streamlit) (4.0.2)
# Collecting blinker<2,>=1.0.0
#   Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Collecting pydeck<1,>=0.8.0b4
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Collecting protobuf<6,>=3.20
#   Using cached protobuf-5.29.4-cp38-cp38-win_amd64.whl (434 kB)
# Collecting pyarrow>=7.0
#   Using cached pyarrow-17.0.0-cp38-cp38-win_amd64.whl (25.2 MB)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\vanathi\anaconda3\lib\site-packages (from streamlit) (5.5.2)
# Collecting requests<3,>=2.27
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting rich<14,>=10.14.0
#   Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Collecting python-dateutil>=2.8.2
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vanathi\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2020.1)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Requirement already satisfied: jinja2 in c:\users\vanathi\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (2.11.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\vanathi\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.2.0)
# Collecting narwhals>=1.5.2
#   Using cached narwhals-1.34.1-py3-none-any.whl (325 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vanathi\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2020.6.20)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vanathi\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.25.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vanathi\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.10)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.4.1-cp38-cp38-win_amd64.whl (102 kB)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting pygments<3.0.0,>=2.13.0
#   Using cached pygments-2.19.1-py3-none-any.whl (1.2 MB)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Requirement already satisfied: six>=1.5 in c:\users\vanathi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vanathi\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\vanathi\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (50.3.1.post20201107)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\vanathi\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\vanathi\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.17.3)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, python-dateutil, tzdata, pandas, narwhals, altair, blinker, pydeck, protobuf, pyarrow, charset-normalizer, requests, mdurl, markdown-it-py, pygments, rich, smmap, gitdb, gitpython, streamlit
# Successfully installed altair-5.4.1 blinker-1.8.2 charset-normalizer-3.4.1 gitdb-4.0.12 gitpython-3.1.44 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.34.1 pandas-2.0.3 protobuf-5.29.4 pyarrow-17.0.0 pydeck-0.9.1 pygments-2.19.1 python-dateutil-2.9.0.post0 requests-2.32.3 rich-13.9.4 smmap-5.0.2 streamlit-1.40.1 tenacity-9.0.0 tzdata-2025.2

# %%
import streamlit as st
import pandas as pd

# Get mood options
mood_options = media["mood_tag_standard"].dropna().unique().tolist()
mood_options.sort()

# Sidebar
st.sidebar.title("🎭 Mood Meets Media")
user_mood = st.sidebar.selectbox("Select your mood", mood_options)

# Optional filters
genre_filter = st.sidebar.text_input("Filter by genre (optional)")
media_type_filter = st.sidebar.selectbox("Filter by media type", ["", "Movie", "TV Show", "Music", "Podcast", "ASMR", "Vlog"])

top_n = st.sidebar.slider("Number of recommendations", 1, 10, 5)

# Recommendation logic
def recommend_with_filters(mood, df, genre=None, media_type=None, top_n=5):
    filtered = df[df["mood_tag_standard"] == mood]
    if genre:
        filtered = filtered[filtered["genre"].str.contains(genre, case=False, na=False)]
    if media_type:
        filtered = filtered[filtered["type"].str.lower() == media_type.lower()]
    return filtered.sample(n=min(top_n, len(filtered)), random_state=42) if not filtered.empty else pd.DataFrame()

# Display recommendations
st.title("🎯 Mood-Based Recommendations")

recommendations = recommend_with_filters(user_mood, media, genre_filter, media_type_filter, top_n)

if not recommendations.empty:
    for _, row in recommendations.iterrows():
        st.subheader(row["title"])
        st.write(f"**Type**: {row['type']} | **Genre**: {row['genre']} | **Mood**: {row['mood_tag_standard']}")
        st.write(f"📄 {row['tags']}")
        st.markdown("---")
else:
    st.warning("No recommendations found for that combination. Try changing filters!")
# Out:
# 2025-04-13 13:38:52.006 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.082
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Vanathi\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-13 13:38:52.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.091 Session state does not function when running a script without `streamlit run`
# 2025-04-13 13:38:52.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-13 13:38:52.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
